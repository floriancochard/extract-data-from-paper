# %% [markdown]
# # Image Processing Pipeline Notebook
#
# This notebook demonstrates the image processing and OCR pipeline steps.

# %%
# Setup and imports
# %reload_ext autoreload
# %autoreload 1
# %aimport core.ocr
# %aimport core.image
# %aimport core.text

import cv2
from core import ocr, image, text
from pathlib import Path
from PIL import Image
import sys
sys.path.append('src')
from main import Pipeline

# Initialize pipeline
pipeline = Pipeline()

# %% [markdown]
# ## Block Segmentation Demo

# %%
def process_blocks(preprocess_path: Path, output_dir: Path, year: str, page: str):
    """Process image blocks and return segmented blocks."""
    blocks = core.Image(preprocess_path, output_dir).block_segmentation()
    block_info = []
    for block_path in blocks:
        block_path = Path(block_path)
        block_num = int(block_path.stem.split('-b')[-1])
        block_info.append((block_path, block_num))
    return block_info

def process_lines(block_path: Path, output_dir: Path, year: str, page: str, block_num: int):
    """Process block lines and return segmented lines."""
    lines = core.Image(block_path, output_dir).line_segmentation()
    line_info = []
    for line_path in lines:
        line_path = Path(line_path)
        # Extract line number from filename (e.g., line_y1922-p028-b0-r5.png -> 5)
        line_num = int(line_path.stem.split('-r')[-1])
        # For now, use a default height since it's not in the filename
        height = 0
        line_info.append((line_path, line_num, height))
    return line_info

def process_block_text(block_path: Path, year: str, page: str, block_num: int):
    """Process block text using OCR."""
    return core.OCR(block_path).block_to_string()

def process_line_text(line_path: Path, year: str, page: str, block_num: int, line_num: int, height: int):
    """Process line text using OCR."""
    return core.OCR(line_path).line_to_string()

# Process blocks
blocks = process_blocks(
    preprocess_path=pipeline.io.PATH_PREPROCESS / 'preprocess_y1922-p028.png',
    output_dir=pipeline.io.PATH_BLOCK,
    year='1922',
    page='028'
)
# Out:
# 2024-12-01 16:49:44,539 - INFO -  Starting - Line                    segmentation in /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/block/block_y1922-p028-b0.png file.
# 2024-12-01 16:49:44,626 - DEBUG - 	 > preprocessing block
# 2024-12-01 16:49:44,626 - DEBUG - 	 > grayscale
# 2024-12-01 16:49:44,628 - DEBUG - 	 > binarize
# 2024-12-01 16:49:44,635 - DEBUG - 	 > segment lines
# 2024-12-01 16:49:44,858 - INFO - 		 > 0-th line                        considered (area = 9748)
# 2024-12-01 16:49:44,863 - INFO - 		 > 1-th line                        considered (area = 135271)
# 2024-12-01 16:49:44,875 - INFO - 		 > 2-th line                        considered (area = 6290)
# 2024-12-01 16:49:44,877 - INFO - 		 > 5-th line                        considered (area = 342418)
# 2024-12-01 16:49:44,902 - INFO - 		 > 6-th line                        considered (area = 21207)
# 2024-12-01 16:49:44,907 - INFO - 		 > 7-th line                        considered (area = 712737)
# 2024-12-01 16:49:44,946 - INFO - 		 > 8-th line                        considered (area = 168831)
# 2024-12-01 16:49:44,958 - INFO - 		 > 9-th line                        considered (area = 20216)
# 2024-12-01 16:49:44,962 - INFO - 		 > 10-th line                        considered (area = 12027)
# 2024-12-01 16:49:44,965 - INFO - 		 > 11-th line                        considered (area = 262960)
# 2024-12-01 16:49:44,980 - INFO - 		 > 13-th line                        considered (area = 517301)
# 2024-12-01 16:49:45,006 - INFO - 		 > 15-th line                        considered (area = 5339)
# 2024-12-01 16:49:45,009 - INFO - 		 > 18-th line                        considered (area = 2149025)
# 2024-12-01 16:49:45,096 - INFO - 		 > 20-th line                        considered (area = 18076)
# 2024-12-01 16:49:45,101 - INFO - 		 > 22-th line                        considered (area = 522163)
# 2024-12-01 16:49:45,133 - INFO - 		 > 24-th line                        considered (area = 18291)
# 2024-12-01 16:49:45,136 - INFO - 		 > 25-th line                        considered (area = 70264)
# 2024-12-01 16:49:45,142 - INFO - 		 > 27-th line                        considered (area = 12074)
# 2024-12-01 16:49:45,145 - INFO - 		 > 28-th line                        considered (area = 20061)
# 2024-12-01 16:49:45,150 - INFO - 		 > 30-th line                        considered (area = 14897)
# 2024-12-01 16:49:45,153 - INFO - 		 > 31-th line                        considered (area = 11208)
# 2024-12-01 16:49:45,155 - INFO - 		 > 32-th line                        considered (area = 67770)
# 2024-12-01 16:49:45,161 - INFO - 		 > 33-th line                        considered (area = 17104)
# 2024-12-01 16:49:45,165 - INFO - 		 > 34-th line                        considered (area = 24337)
# 2024-12-01 16:49:45,170 - INFO - 		 > 35-th line                        considered (area = 20743)
# 2024-12-01 16:49:45,173 - INFO - 		 > 36-th line                        considered (area = 11664)
# 2024-12-01 16:49:45,175 - INFO - 		 > 38-th line                        considered (area = 9716)
# 2024-12-01 16:49:45,177 - INFO - 		 > 39-th line                        considered (area = 94828)
# 2024-12-01 16:49:45,185 - INFO - 		 > 40-th line                        considered (area = 16573)
# 2024-12-01 16:49:45,188 - INFO - 		 > 41-th line                        considered (area = 11717)
# 2024-12-01 16:49:45,190 - INFO - 		 > 43-th line                        considered (area = 9766)
# 2024-12-01 16:49:45,193 - INFO - 		 > 44-th line                        considered (area = 70113)
# 2024-12-01 16:49:45,199 - INFO - 		 > 45-th line                        considered (area = 56731)
# 2024-12-01 16:49:45,207 - INFO - 		 > 46-th line                        considered (area = 159517)
# 2024-12-01 16:49:45,219 - INFO - 		 > 47-th line                        considered (area = 21990)
# 2024-12-01 16:49:45,222 - INFO - 		 > 48-th line                        considered (area = 15427)
# 2024-12-01 16:49:45,225 - INFO - 	> Terminated - line segmentation for lines in block             0 terminated in 0 seconds.
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r0.png
# 0° Nﬂmv'ih ONQOO NNﬁ‘f'ﬁ «annexe H 0
# H POND-(HM HHHHN NNNNN NNNNM M E
#
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r1.png
# - PREP Q 7) 4 FG][NEW]OF g48 EXE 2®E #329 g[NEW]Tg SEs EA 238 824[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r2.png
# i a "000 000 000 00:3 0
# u—qn ~~~ u-cn 1-1-1 u-
#
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r5.png
# Wm 4DOO0E ULLOT HQ0MY Snow 9 WORE LuNON 2 §[NEW]MN HW N [al nO OO ~<a [:] wy ~N on ON I on << [sl (12) g[NEW]Ss 638857 $8385 T885Y 88883 SISEY 38%: 8[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r6.png
# is
# 4999”? 93,599» 5910099 99mm swaps“? antrsw-ﬁ (S 38“ u
# E nnNumr‘ ulﬂlﬁmﬂ AAHHA AMHMIR ﬁmﬁaﬂlﬂ IARIAUA n m- 91
#
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-
Mm HNO MONG O FTNIND WO AINA In S A[NEW]z 25 - 8 © <q 4 RAD nYn (08 B93 0D = T 5 Sgrnng QoQN® QBAGN AoNm- DRAFE henmbh § BC[NEW]Ld . -[NEW]58 . 4% § ds § gFEF ESE NEY SEE I wg = EB3EEE BTZRT 85588 gEE5Y g8¥5E 555d 8 8 2[NEW]gd ES = Hg 8 8 Z 50 A PR SR » R= i. FE[NEW]3 a nw oa > . -S9%8 TY megR Ann 8 R 8 f= IM FAMEY HO0O0RS ORIN AOL TH ODT F - o[NEW]Zs § gf & BF 5 ERE REE EET EER YF ¢ 3 €S8EEY JEE8T 55855 3¥EEe SEEEl gE yy 0% 3[NEW]= OS z 8g 3 TR URN nA A a A gE 2 4 TTION QaNMY OTNAO MNOOO®M NHEBM 00 ¥ FO .[NEW]z, 0 § 5S Zw 553% 99% $8¢ 388 § 2x i foyogn pooo: SEESY JOSEY DS99F $9888 | 3[NEW]o Zg - 2s FS o ° a E909 20 282 222.2 n= = 05000 00000 050&8338 090006 00888 88 9 3[NEW]= S 8 o = 5 - : B13 : NO OWN FOAM VOTO FIN AMAOG WHMNTEN ONO NY I~ 3[NEW]< 88 2 8 § 4 538% £88 238 gem g MO £ 235338 SSUST SoESD B3EIC BESS 2usye TF[NEW]=~ ok | o ts o hE) * CAAT 23% 2382 239 3 al & = Egg aia 060080 00088 2885 $8883 833858 5 8 Qe[NEW]RCS Ea g 3 ER ING NM NN DAN 8 S$ |,  emoO0Y ODM O MNOOWN neamon mmsmoe mmeeo © 00 § 8[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r20.png
# ' -r“f’9'.’“.‘ P9209? fﬁ‘f’ﬁ'ﬂ‘Q we‘ve“? ‘9‘9‘3’9‘0 "muww m -
# 5 Lung..." nmmwn “Mann ”Hum.” ...\.,.~;.. A;;.;.A | 0- ﬂ
#
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r22.png
# ; 5999 wom yuo mom 0[NEW]® £900 000 000 000 © ool[NEW]FI+ +010 ti +++ 0[NEW]Csr ov ow oo SEPT BF OBEY EFS OZER og -[NEW]2 CE S-] ~ B99 °99 $%°% 99% § [> & MH gRONIe ZIBOL S0TON NOATE OHNON © FROO Pp &[NEW][=] E He mem ~OQOoW OHAQR HAMME QQ MME FTOYoo | 0 >[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r24.png
# a goooO QO 000 Ooo id[NEW]TH+ +++ H+ FHF +[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r25.png
# 8 LS S5mw wom © NO a ~~ 0 NO 6 NOD mu RNIN Ed woo & no Qs[NEW]Rk OW Fm no 8 ony LO NO® =H ONO TNO NI - Ce[NEW]. = H3888S T5585 $8555 S558 §5558 S888 & 50[NEW][NEW]_ be[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r27.png
# ST = I A AA NC[NEW]§ Eo900 ©00 000 000 oO[NEW]Til 4dr 44+ S411[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r28.png
# >s
# - we??? sun-ﬁre's reams? print“? 99955 wmmww o 2 "a.
# _S nﬂmm-ﬂ-M mun-Auk Nmnmm ﬁﬁmM-A ”rank; LARA-L n:- In- A
#
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r30.png
# ; 98% FoF BeW S58 3[NEW]o P= EO EAE A PIA ~~ ~[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r31.png
# gQO0O 000 OOO oOo wv[NEW]+++ FHF FHF FEE OF[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r32.png
# » ECA EE CAN A MAR A - E  CEN d m B[NEW]AH Hm HAND NH Hn MAmmMmIn © Mn s+ Tnny | 0[NEW][NEW]gS E8828 8 288% 5 SSY58 o8y8s 88829 ON tm ° fod[NEW][NEW]© 0 00 © [+ 000 [=2N~] oOo 000O0O -[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r33.png
# 5 Boo0o0 000 0006 000 Oo[NEW]I3I¥F F4+ F¥++ +++ +[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r34.png
# [> RE M[NEW]Zi 4 09m HY GTM 0D ONNOMm NNTNO FO FRR AE[NEW]WS AO «MDD HOM HH NH HIAWIe IMAM MI WO MINN $d innw |] 0[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r35.png
# . SNOY FMR amd aww mn[NEW]2] dC Ce ~ on pa ~~ ~~ ~~[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r36.png
# go 0o9 OC OG Ou VOW Ad[NEW]+++ FFF FFF FHF OF[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r38.png
# NEE « OER a wi EE AC[NEW]§ Eooo coe ooo ode ©[NEW]ITI 13d Lad rd[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r39.png
# : @ THOR MONINM WHO FTE DOWNKM NTT T NTO RO © Py[NEW]8 282m QHQER WAQHN QyNOQ ©P0 Ln T0o8s | % =[NEW]- 2 E38E33 F388% 85855 §E§5S §E5ES I58%% g[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r40.png
# N WN. nog hg oN NO Is )[NEW]. 508% DIR IBY TB 3B[NEW]~N Ad + A. Pst PY[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r41.png
# g§9 90 OQ fe ene] gow 4[NEW]+++ +++ +++ HH +[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r43.png
# OE «BOGE A EE GE GC[NEW]bes §©00 ©0©0 000 C00 ©[NEW]Lal edd dd 44[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r44.png
# H Goat Hadel INMOLUMmM MINAOI OT00 Mk Bonde wv 7 oa[NEW]OO NN Oe pega NNQ OWN $2885 §épx wn[NEW]~ MN[NEW]5 #58585 §§58Y £5855 FE388 85883 88355 8 § 3[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r45.png
# = i ONOFH ODMEE FHOWY DUET VXOOME THON © 8[NEW]BA HORNE Hema gdl NMOMMm MInA on Oto OO thos wn 4)[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r46.png
# d 400009 WONOW HOIYF> QFONT XoNMRn Quved oa a[NEW]. hE ™~ ONO® ¥ oN [n= now < - SAR 22 SS « 3°[NEW]~[NEW]g 4 = S8385F B58BF FUREY ¥ERSE LIREN 28R4% 5 &[NEW]pe. -[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r47.png
# : MMH 0 0 VOMON HEF FL AFM DVDONPN QANOOD F:][NEW]H LO CONN ONODET MO MMO WIND TO FRMO IN re (Nh ned wo TN[NEW]
#
# Source: /Users/floriancochard/Documents/extract_data_from_paper/src/data/output/line/line_y1922-p028-b0-r48.png
# WRW RVI MNO HYPO[NEW]sO8% TRY PPS 33F 5[NEW]hd +2 0 D-- PA A- iN ~[NEW]

# %% [markdown]
# ## Pipeline Execution

# %%
# Process method-specific segmentation
method = pipeline.params.METHOD
strings = []

try:
    if method == "BLOCK":
        for block_path, block_num in blocks:
            string = process_block_text(block_path, '1922', '028', block_num)
            strings.append(string)
            
    elif method == "LINE":
        for block_path, block_num in blocks:
            lines = process_lines(block_path, pipeline.io.PATH_LINE, '1922', '028', block_num)
            for line_path, line_num, height in lines:
                string = process_line_text(line_path, '1922', '028', block_num, line_num, height)
                strings.append(string)
    else:
        raise ValueError(f"Unsupported method: {method}")
except Exception as e:
    print(f"Error processing images: {str(e)}")
# Out:
# Error processing images: too many values to unpack (expected 2)
